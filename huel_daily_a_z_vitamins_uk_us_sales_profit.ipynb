# %%
import csv
from datetime import datetime

# define output file
output_csv = "huel_daily_a_to_z_sales_demographics.csv"

# define headers
headers = [
    # Basic identifiers
    "Region",          # "UK" or "US"
    "Year",            # e.g., 2025
    "Month",           # e.g., 1-12 or "2025-01"
    # Sales/profit data
    "UnitsSold",       # number of units sold in period
    "NetRevenue",      # net revenue after discounts & returns
    "CostOfGoodsSold", # direct product costs
    "GrossProfit",     # NetRevenue - CostOfGoodsSold
    "GrossMarginPct",  # GrossProfit / NetRevenue * 100
    "MarketingSpend",  # marketing expense
    "OperatingProfit", # optional, if available
    "OperatingMarginPct", # optional
    # Demographics
    "TopAgeGroupPct",      # e.g. percent in top age bracket
    "TopGenderPct",        # e.g. percent male or female or other
    "TopIncomeBracketPct", # percent for top income group
    # Additional notes
    "Comments"
]

# Example dummy rows (clearly labeled as placeholders)
example_rows = [
    {
        "Region": "UK",
        "Year": "2025",
        "Month": "1",
        "UnitsSold": "12000",       # dummy placeholder
        "NetRevenue": "227880",     # dummy placeholder GBP
        "CostOfGoodsSold": "120000",# dummy placeholder GBP
        "GrossProfit": "",          # leave blank to compute
        "GrossMarginPct": "",       # leave blank to compute
        "MarketingSpend": "45000",  # dummy placeholder GBP
        "OperatingProfit": "",      # optional
        "OperatingMarginPct": "",   # optional
        "TopAgeGroupPct": "35",     # dummy percent
        "TopGenderPct": "55",       # dummy percent
        "TopIncomeBracketPct": "40",# dummy percent
        "Comments": "Dummy data. Replace with verified figures."
    },
    {
        "Region": "US",
        "Year": "2025",
        "Month": "1",
        "UnitsSold": "8000",        # dummy placeholder
        "NetRevenue": "300000",     # dummy placeholder USD
        "CostOfGoodsSold": "150000",# dummy placeholder USD
        "GrossProfit": "",          # leave blank to compute
        "GrossMarginPct": "",       # leave blank to compute
        "MarketingSpend": "60000",  # dummy placeholder USD
        "OperatingProfit": "",      # optional
        "OperatingMarginPct": "",   # optional
        "TopAgeGroupPct": "40",     # dummy percent
        "TopGenderPct": "50",       # dummy percent
        "TopIncomeBracketPct": "30",# dummy percent
        "Comments": "Dummy data. Replace with verified figures."
    }
]

# Write to CSV
with open(output_csv, mode="w", newline="", encoding="utf-8") as f:
    writer = csv.DictWriter(f, fieldnames=headers)
    writer.writeheader()
    for row in example_rows:
        writer.writerow(row)

print(f"Template CSV created: {output_csv}")
# Out:
# Template CSV created: huel_daily_a_to_z_sales_demographics.csv
